# %%
import pickle

# %%
import mplfinance
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import mplfinance
#
# ModuleNotFoundError: No module named 'mplfinance'

# %%
# !conda info -v
# Out:
#      active environment : py312
#     active env location : /opt/homebrew/Caskroom/miniconda/base/envs/py312
#             shell level : 1
#        user config file : /Users/orangeao/.condarc
#  populated config files : /opt/homebrew/Caskroom/miniconda/base/.condarc
#                           /Users/orangeao/.condarc
#           conda version : 25.9.1
#     conda-build version : not installed
#          python version : 3.13.5.final.0
#                  solver : libmamba (default)
#        virtual packages : __archspec=1=m1
#                           __conda=25.9.1=0
#                           __osx=14.5=0
#                           __unix=0=0
#        base environment : /opt/homebrew/Caskroom/miniconda/base  (writable)
#       conda av data dir : /opt/homebrew/Caskroom/miniconda/base/etc/conda
#   conda av metadata url : None
#            channel URLs : https://repo.anaconda.com/pkgs/main/osx-arm64
#                           https://repo.anaconda.com/pkgs/main/noarch
# ...

# %%
# !which pip
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/py312/bin/pip

# %%
sqlite3.Timestamp(1, 3, 2, )
# Out:
# datetime.datetime(1, 3, 2, 0, 0)
